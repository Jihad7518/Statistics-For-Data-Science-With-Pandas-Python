# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Survived"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
plt.pie(df["Survived"].value_counts().values)
plt.legend( df["Survived"].value_counts().index)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
new_dataframe  = df[ df["Age"] < 10 ]
new_dataframe["Survived"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df[ ["Sex"] ].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Sex'>

# %%
df[ ["Sex","Survived"] ].groupby(["Sex"]).sum().plot.bar()
# Out:
# <Axes: xlabel='Sex'>

# %%
df[ ["Sex","Pclass","Survived"] ].groupby(["Sex","Survived","Pclass"]).value_counts()
# Out:
# Sex     Survived  Pclass
# female  0         1           3
#                   2           6
#                   3          72
#         1         1          91
#                   2          70
#                   3          72
# male    0         1          77
#                   2          91
#                   3         300
#         1         1          45
#                   2          17
#                   3          47
# dtype: int64

# %%
df[ ["Sex","Pclass","Survived"] ].groupby(["Sex","Survived"]).value_counts()
# Out:
# Sex     Survived  Pclass
# female  0         3          72
#                   2           6
#                   1           3
#         1         1          91
#                   3          72
#                   2          70
# male    0         3         300
#                   2          91
#                   1          77
#         1         3          47
#                   1          45
#                   2          17
# dtype: int64

# %%
sns.countplot( df , x="Sex" , hue ="Survived" )
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.corr()
# Out:
# <ipython-input-42-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %%
sns.heatmap( df.corr() )
# Out:
# <ipython-input-43-f89ddc8a2d14>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap( df.corr() )
# <Axes: >

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2])

# %%
def bar_plot(column_name):
  values = df[column_name]
  values.value_counts().plot.bar()
  plt.show()

bar_plot("Sex")
bar_plot("Embarked")
bar_plot("Pclass")
